# %% [markdown]
# # TL-Test: The Unified TileLink Memory Subsystem Tester for XiangShan

# %%
# %%bash
# cd ../ && source env.sh
# Out:
# SET XS_PROJECT_ROOT: /nfs/home/liuweiding/tutorial-xs-env
# SET NOOP_HOME (XiangShan RTL Home): /nfs/home/liuweiding/tutorial-xs-env/XiangShan
# SET NEMU_HOME: /nfs/home/liuweiding/tutorial-xs-env/NEMU
# SET AM_HOME: /nfs/home/liuweiding/tutorial-xs-env/nexus-am
# SET DRAMSIM3_HOME: /nfs/home/liuweiding/tutorial-xs-env/DRAMsim3
# SET gem5_home: /nfs/home/liuweiding/tutorial-xs-env/gem5
# SET TLT_HOME: /nfs/home/liuweiding/tutorial-xs-env/tl-test-new
# SET TUTORIAL_HOME: /nfs/home/liuweiding/tutorial-xs-env/tutorial
# SET READY2RUN_HOME: /nfs/home/liuweiding/tutorial-xs-env/tutorial/ready-to-run

# %%
# %%bash
# cd ../ && source env.sh > /dev/null
# # make coupledL2-test-l2l3-v3 run THREADS_BUILD=16 CXX_COMPILER=clang++-17
# cd $TLT_HOME/run && ./tltest_v3lt 2>&1 | tee tltest_v3lt.log
# Out:
# bash: line 3: cd: /nfs/home/liuweiding/tutorial-xs-env/tl-test-new/run: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd ../ && source env.sh > /dev/null\n# make coupledL2-test-l2l3-v3 run THREADS_BUILD=16 CXX_COMPILER=clang++-17\ncd $TLT_HOME/run && ./tltest_v3lt 2>&1 | tee tltest_v3lt.log\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
# ...

# %%
# %%bash
# cd ../ && source env.sh > /dev/null
# grep "addr: 0x16000" $TLT_HOME/run/tltest_v3lt.log
